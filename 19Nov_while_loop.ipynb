# %%
count=1
while count<=5:   #jabtak tum is while
    print("Count is: ",count)
    count += 1
# Out:
# Count is:  1
# Count is:  2
# Count is:  3
# Count is:  4
# Count is:  5

# %%
fruits=['apple','banana','grape','kiwi']

# %%
for i in fruits:
    print(i)
# Out:
# apple
# banana
# grape
# kiwi

# %%
for i in range(len(fruits)):
    print(fruits[i])
# Out:
# apple
# banana
# grape
# kiwi

# %% [markdown]
# num_list = [.......]
# check_element=""
# check_flag = False
#
# for element in num_list:
#     if check element == element:
#         check_flag = True
#         break
#     else:
#
# if check_flag:
#     print("Element was found")
#
# else:
#     print('Element not found')

# %%
num_list = [10, 20, 30, 40, 50]   # Example list
check_element = 30               # Element to check
check_flag = False

for element in num_list:
    if check_element == element:
        check_flag = True
        break

if check_flag:
    print("Element was found")
else:
    print("Element not found")
# Out:
# Element was found

# %% [markdown]
# Assignment:
#
# list_of_numbers=[87,45,1,100,200,42,56,.......]
# first convert it into set
# convert that set into a list
# sorted()
#
# list_of_numbers = []

# %%
list_of_numbers = [87, 45, 1, 100, 200, 42, 56, 87, 1]  

num_set = set(list_of_numbers)

unique_numbers_list = list(num_set)

list_of_numbers = sorted(unique_numbers_list)

print(list_of_numbers)
# Out:
# [1, 42, 45, 56, 87, 100, 200]

# %%
i=1
while True:
    if i>5:
        break
    print(i)  
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=0
while i<=5:
    i+=1

    if i==3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
# 459=4+5+9

number=int(input("Enter a 3 digit number"))
print("the number is ",number)
total=0

while number>0:
    digit = number%10
    total+=digit
    number //=10


print("sum of digits: ",total)
# Out:
# the number is  459
# sum of digits:  18

# %%
## interview ques

number=int(input('Enter the number'))
print("number is ",number)
reversed_number=0

while number>0:
    digit=number%10
    reversed_number=reversed_number*10 + digit
    number //=10

print("Reversed number is: ",reversed_number)
# Out:
# number is  459
# Reversed number is:  954

# %%
##Assignment

index_0 = 0

index_last = len(list_name)

mid_index = index_last//2



list_name[mid_index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 ##Assignment
#       3 index_0 = 0
# ----> 5 index_last = len(list_name)
#       7 mid_index = index_last//2
#      11 list_name[mid_index]
#
# NameError: name 'list_name' is not defined

# %%
# Assignment : Find the number if it exists by splitting the list in half 
list_kuch_items = [10, 20, 30, 40, 50, 60, 70]

first_element = list_kuch_items[0]
akhiri_element = list_kuch_items[-1]
middle_index = len(list_kuch_items) // 2
middle_element = list_kuch_items[middle_index]

print("First:", first_element)
print("Middle:", middle_element)
print("Last:", akhiri_element)
# Out:
# First: 10
# Middle: 40
# Last: 70

# %%
list_name = [5, 10, 15, 20, 25, 30]

index_0 = 0
index_last = len(list_name)
mid_index = index_last // 2

middle_value = list_name[mid_index]

print("Middle element is:", middle_value)
# Out:
# Middle element is: 20

# %% [markdown]
# #assignment
# list=[]
# first_element=list_kuch_items[0]
# akhiri_element=list_kuch_items[-1]
# middle_element=len(list_kuch_items)//2
