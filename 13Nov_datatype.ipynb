# %%
print("hello")
# Out:
# hello

# %%
a=[10,20,30,40]

# %%
b=a

# %%
b
# Out:
# [10, 20, 30, 40]

# %%
b=a.copy()

# %%
a[0]=99
print(a)
# Out:
# [99, 20, 30, 40]

# %%
b
# Out:
# [10, 20, 30, 40]

# %%
type(a)
# Out:
# list

# %%
#datatypes

# %%
integer_a=12
float_b=21.22

# %%
print(type(integer_a))
# Out:
# <class 'int'>

# %%
complex_num=2+3j

# %%
print(type(complex_num))
# Out:
# <class 'complex'>

# %%
num=12
bin_num=bin(num)

print(bin_num)
# Out:
# 0b1100

# %%
oct_num=oct(num)

print(oct_num)
# Out:
# 0o14

# %%
float_num=float(num)

print(float_num)
# Out:
# 12.0

# %%
hex_num=hex(num)
print(hex_num)
# Out:
# 0xc

# %%
num_1=int(input("enter 1st num"))
num_2=int(input("enter 2nd num"))
# Out:
# enter 1st num 8
# enter 2nd num 9

# %%
result=num_1+num_2

# %%
print(result)
# Out:
# 17

# %% [markdown]
# Mathematical oprations
# addition +
# multiplictn *
# divsiom / or //
# sub -
# remainder%

# %% [markdown]
# principal*rate*time/100

# %%
a=float(input("Enter the principal amount"))
b=float(input("Enter the principal amount"))
c=float(input("Enter the principal amount"))
simple_interest=(a*b*c/100)
print(simple_interest)
# Out:
# Enter the principal amount 55555
# Enter the principal amount 5
# Enter the principal amount 4
# 11111.0

# %%
celcius=20
farhen=(celcius*9/5)+32

print(farhen)
# Out:
# 68.0

# %%
principal=float(input("Enter the princiapl amt"))
roi= float(input("Enter the rate of interest"))
time= float(input("Enter the time"))

simple_int=principal*roi*time/100

print("Simple Interest:",simple_int)
# Out:
# Enter the princiapl amt 100000
# Enter the rate of interest 4.5
# Enter the time 5
# Simple Interest: 22500.0

# %% [raw]
# weight--> input
# height--> height (in mtrs)
# bmi=weight/(height**2)

# %%
weight=int(input("Enter:"))
height=int(input("Enter in mtrs:"))
bmi=weight/(height**2)

print(bmi)
# Out:
# Enter: 55
# Enter in mtrs: 5
# 2.2

# %%
##area of circle
pi=3.14
radius=3
aoc=pi*(radius**2)

print("area of circle:",aoc)
# Out:
# area of circle: 28.26

# %% [raw]
# 1usd = 83 rupees
#
# usd to inr
# inr to usd

# %%
inr=int(input("how many rps do u have:"))
usd = inr/83
print("u have:",usd,"dollars")
# Out:
# how many rps do u have: 56
# u have: 0.6746987951807228 dollars

# %%
usd=int(input("how many dollars do u have:"))
inr=usd*83
print("u have:",inr,"rupees")
# Out:
# how many dollars do u have: 52
# u have: 4316 rupees

# %%
product1= int(input("Enter the value of product 1:"))
product2= int(input("Enter the value of product 2:"))
product3= int(input("Enter the value of product 3:"))

total_amt=product1+product2+product3

final_amt=total_amt-(total_amt*20/100)

print(final_amt)
# Out:
# Enter the value of product 1: 200
# Enter the value of product 2: 600
# Enter the value of product 3: 300
# 880.0

# %%
discount_amt=total_amt*20/100
print("Discounted price:",discount_amt)
# Out:
# Discounted price: 220.0

# %%
final_amt
# Out:
# 880.0
