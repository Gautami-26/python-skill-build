# %% [markdown]
# ## IF ELSE

# %%
number_input=int(input("Enter a number"))

if number_input>0:
    print("it is a positive number")

else:
    print("The number is either 0 or negative")
# Out:
# it is a positive number

# %%
aaj_ka_temp=int(input("Enter a today temp:"))

if aaj_ka_temp>15:
    print("mai cold drink piyunga")
else:
    print("bring me a cup of hot coffe")

# %%
print("Enter 1 for usd to 2 Inr OR 2 for INR to USD")
money_exchange_choice=int(input("Enter your choice"))
amt=int(input("Enter yout amount:"))

if money_exchange_choice==1:
    current_balance=83*(amt)
    print("INR:",current_balance)

elif money_exchange_choice==2:
    current_balance=amt/83
    print("USD:",current_balance)

else:
    print("Wrong input given")
# Out:
# Enter 1 for usd to 2 Inr OR 2 for INR to USD
# Enter your choice 1
# Enter yout amount: 4555
# INR: 378065

# %%
print("Enter the score of 5 subjects")

sub1=int(input("Enter the score of Sub1:"))
sub2=int(input("Enter the score of Sub2:"))
sub3=int(input("Enter the score of Sub3:"))
sub4=int(input("Enter the score of Sub4:"))
sub5=int(input("Enter the score of Sub5:"))

total=sub1+sub2+sub3+sub4+sub5

avg = total/5
print("Average:",avg)

if avg >=90:
    print('Grade A')
    
elif avg>=80:
    print("Grade B")

elif avg>=70:
    print("Grade C")

elif avg >=60:
    print("Grade D")

else:
    print("Failed!!")
# Out:
# Enter the score of 5 subjects
# Enter the score of Sub1: 98
# Enter the score of Sub2: 65
# Enter the score of Sub3: 87
# Enter the score of Sub4: 95
# Enter the score of Sub5: 79
# Average: 84.8
# Grade B

# %%
##even and odd
##num%2==0

print('Check whether number is odd or even:')

num=int(input("enter the number:"))

if num%2==0:
    print(num," is even number")

else:
    print(num," is odd number")
# Out:
# Check whether number is odd or even:
# enter the number: 5
# 5  is odd number

# %%
valid_user_id="gautami"
valid_pwd="1234"

input_user_id=input("Enter user id:")
input_pwd= input("Enter pwd:")

print("Entered user id is:",input_user_id)
print("Entered passwrd is:",input_pwd)

if input_user_id == valid_user_id or input_pwd == valid_pwd:
    print("Login Successfull")
else:
    print("Entered id or pwd is wrong")
# Out:
# Enter user id: gautamii
# Enter pwd: 4563
# Entered user id is: gautamii
# Entered passwrd is: 4563
# Entered id or pwd is wrong

# %%
##condition1 for leap year : 4 se divide lekin 100 se nhi hona chahiye
##condition 2 :400 se divide

year_input=int(input("Enter the year:"))
if (year_input%4==0 and year_input%100!=0) or (year_input%400==0):
    print("It is a leap year")

else:
    print("It is not leap year")
# Out:
# Enter the year: 2004
# It is a leap year

# %%
##all sides are equal 
##only 2 sides are eq
##none of the sides are eq

# %%
## person --> indian,age18 ,voter_id

print("Is person is eligible for voting")
age=int(input("\nenter your age:"))
citizen="indian"
voter_id=input("do yo have voter id(Y or N):")

if citizen=="indian" and age>18 and voter_id=="y":
    print("U can vote")

else:
    print("U cannot vote")
# Out:
# Is person is eligible for voting
# enter your age: 60
# do yo have voter id(Y or N): y
# U can vote

# %% [markdown]
# assignment:
# if number is divisible by 5 and if its even number or odd

# %%
num= int(input("enter the value:"))
if num%5==0 and num%2==0:
    print("Number is divisible by 5 and it is even number")
else:
    print("Number is not divisible by 5 and it is odd num")
# Out:
# enter the value: 10
# Number is divisible by 5 and it is even number

# %%
## if india vs australia if india has more runs then india will win
