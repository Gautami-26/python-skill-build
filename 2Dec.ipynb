# %%
class Student:
    def __int__(self,name):
        self.name=name
        
s1=Student("Pratik")
print(s1.name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2     def __int__(self,name):
#       3         self.name=name
# ----> 4 s1=Student("Pratik")
#       5 print(s1.name)
#
# TypeError: Student() takes no arguments

# %%
class Student:
    training_institute_name="Ethans"

    def __init__(self,training_institute_name):
        self.training_institute_name=training_institute_name

student_data=Student("Gautami")  
print(student_data.training_institute_name)
# Out:
# Gautami

# %%
class Demo:
    def show(self):
        x=10
        print(x)
d=Demo()
d.show()
# Out:
# 10

# %%
class Car:
    wheels=4
    def __init__(self,name):
        self.name=name

# %%
class Car:
    wheels=4
    def __init__(self,name):
        self.name=name

c1=Car("BMW")
c2=Car("scorpio")

#c1.wheels=5
#c2.wheels=6


print("printing Car.wheels",Car.wheels)
print("printing Car.wheels",c1.wheels)
print("printing Car.wheels",c2.wheels)

c1.wheels=5

print("2nd printing Car.wheels",Car.wheels)
print("2nd printing Car.wheels",c1.wheels)
print("2nd printing Car.wheels",c2.wheels)

Car.wheels=6

print("3rd printing Car.wheels",Car.wheels)
print("3rd printing Car.wheels",c1.wheels)
print("3rd printing Car.wheels",c2.wheels)
# Out:
# printing Car.wheels 4
# printing Car.wheels 4
# printing Car.wheels 4
# 2nd printing Car.wheels 4
# 2nd printing Car.wheels 5
# 2nd printing Car.wheels 4
# 3rd printing Car.wheels 6
# 3rd printing Car.wheels 5
# 3rd printing Car.wheels 6

# %%
class Counter:
    count=0
    def __init__(self):
        Counter.count+=1
a=Counter()
b=Counter()

print(Counter.count)
# Out:
# 2

# %%
#instance variable created inside method

class Person:
    
    def create(self):
        self.age=25

p=Person()
p.create()
print(p.age)
# Out:
# 25

# %%
class Person:
    age = 18   

    def __init__(self):
        self.age = 25  
        
    
p = Person()

print("printing Person.age:", Person.age)
print("printing p.age:", p.age)

p.age = 30

print("2nd printing Person.age:", Person.age)
print("2nd printing p.age:", p.age)

Person.age = 40

print("3rd printing Person.age:", Person.age)
print("3rd printing p.age:", p.age)
# Out:
# printing Person.age: 18
# printing p.age: 25
# 2nd printing Person.age: 18
# 2nd printing p.age: 30
# 3rd printing Person.age: 40
# 3rd printing p.age: 30

# %%
class Person:
    age=0
    def crete(self):
        self.age=25
        
p=Person()
print("print age:",Person.age)
print("print age:",p.age) 
print("========================")

p.create()
print("after calling create:",Person.age)
print("print age:",p.age) 
print("========================")

Person.age=40
print("Last after calling create:",Person.age)
print("Last print age:",p.age) 
print("========================")
# Out:
# print age: 0
# print age: 0
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 10
#       7 print("print age:",p.age)
#       8 print("========================")
# ---> 10 p.create()
#      11 print("after calling create:",Person.age)
#      12 print("print age:",p.age)
#
# AttributeError: 'Person' object has no attribute 'create'

# %%
# mann.malleswari@tcs.com fro py developer

#

# %%
class Product:
    discount=10

    def __init__(self,name,price):
        self.name=name
        self.price=price

    def final_price(self):
        return self.price - (self.price*Product.discount/100)   

p=Product("Laptop",50000)
print(p.final_price())
# Out:
# 45000.0

# %%
#



class Product:
    discount=10

    def __init__(self,name,price):
        self.name=name
        self.price=price

        def amar():''
        'value return hona hai:20'

    def final_price(self):
        return self.price - (self.price*Product.discount/100)   

p=Product("Laptop",50000)
print(p.final_price())
