# %%
text="Hello Ethans students,welcome to IIT Branch"

# %%
print(text)
# Out:
# Hello Ethans students,welcome to IIT Branch

# %%
text.lower()
# Out:
# 'hello ethans students,welcome to iit branch'

# %%
text.upper()
# Out:
# 'HELLO ETHANS STUDENTS,WELCOME TO IIT BRANCH'

# %%
text.split()
# Out:
# ['Hello', 'Ethans', 'students,welcome', 'to', 'IIT', 'Branch']

# %%
text.strip()
# Out:
# 'Hello Ethans students,welcome to IIT Branch'

# %%
text_1="     Hello Gautami..how r u??    hope u r fine...     study well.  "

# %%
text.strip()
# Out:
# 'Hello Ethans students,welcome to IIT Branch'

# %%
# strip function neglect the space strating and ending of text

# %%
text="Hello Ethans students,welcome to IIT Branch"

# %%
text= text.replace("Hello","Namaste")

# %%
text.find('students')
# Out:
# 15

# %%
text
# Out:
# 'Namaste Ethans students,welcome to IIT Branch'

# %%
text[1:6]
# Out:
# 'amast'

# %%
text[0:6]
# Out:
# 'Namast'

# %%
text[:6]
# Out:
# 'Namast'

# %%
text[:]
# Out:
# 'Namaste Ethans students,welcome to IIT Branch'

# %%
text[-6:]
# Out:
# 'Branch'

# %%
text[:-1]
# Out:
# 'Namaste Ethans students,welcome to IIT Branc'

# %%
text[-1:]
# Out:
# 'h'

# %% [markdown]
# ## interview question
#
# # variable_name[start:stop:step]

# %%
text[::-1]  #reverse string
# Out:
# 'hcnarB TII ot emoclew,stneduts snahtE etsamaN'

# %%
name="AFEFA"
name_palindrome=name[::-1]

if name==name_palindrome:
    print("It is palindrom")

else:
    print("It is not palindrome")
# Out:
# It is palindrom

# %%
name=input("Enter the text")
name_palindrome=name[::-1]

if name==name_palindrome:
    print("It is palindrome")

else:
    print("It is not palindrome")
# Out:
# It is palindrome

# %%
text="Hello Ethans students,welcome to IIT Batch"

# %%
len(text)
# Out:
# 42

# %%
len(text.split())
# Out:
# 6

# %%
text1="hello Gautami....how r u?? hope you r fine,, study well!!!!"

# %%
text.count(".") ##count fun is used for count the occurece of word
# Out:
# 0

# %%
text1.count(".")
# Out:
# 4

# %%
text1.count("...")
# Out:
# 1

# %%
text1.count("!")
# Out:
# 4

# %%
name="amar"
marks=85
print("name:", name, " and marks:",marks)
# Out:
# name: amar  and marks: 85

# %%
print("my name is {} and marks: {}".format(name, marks))
# Out:
# my name is amar and marks: 85

# %%
print("my name is {} and marks: {}".format(marks, name))
# Out:
# my name is 85 and marks: amar

# %%
print(f"my name is {name} and marks: {marks}")
# Out:
# my name is amar and marks: 85

# %% [markdown]
# list_1=[]
#
# tuple_1=()
#
# set_1={}

# %%
students=['sonali','akshay','akash','rohini','yash']

# %%
students[1:3]
# Out:
# ['akshay', 'akash']

# %%
students[:2]
# Out:
# ['sonali', 'akshay']

# %%
students.append("mayuri")

# %%
students
# Out:
# ['sonali', 'akshay', 'akash', 'rohini', 'yash', 'mayuri']

# %%
students.append("virat")

# %%
students
# Out:
# ['sonali', 'akshay', 'akash', 'rohini', 'yash', 'mayuri', 'virat']

# %%
students.remove("virat")

# %%
students
# Out:
# ['sonali', 'akshay', 'akash', 'rohini', 'yash', 'mayuri']

# %%
students.sort()

# %%
students
# Out:
# ['akash', 'akshay', 'mayuri', 'rohini', 'sonali', 'yash']

# %%
numbers= [10,20,30,40,50]

# %%
total=sum(numbers)
total
# Out:
# 150

# %%
numbers=[123,45465,766756,753435,34566,24667,454557,546774]

total=sum(numbers)
total
# Out:
# 2626343

# %%
largest=max(numbers)
largest
# Out:
# 766756

# %%
smallest=min(numbers)
smallest
# Out:
# 123

# %%
#tuples can not be changes or edited

# %%
tuple_1=(1,2,3,4,"pune")

# %%
type(tuple_1)
# Out:
# tuple

# %%
#set
list_1=[1,2,3,4,2,5,6,7,35,6,6,32,45,65,345]

# %%
new_view=set(list_1)

# %%
new_view
# Out:
# {1, 2, 3, 4, 5, 6, 7, 32, 35, 45, 65, 345}

# %%
type(new_view)
# Out:
# set

# %%
naya_list=list(new_view)

# %%
naya_list
# Out:
# [32, 1, 2, 3, 4, 5, 6, 7, 35, 65, 45, 345]

# %%
type(naya_list)
# Out:
# list

# %%
list1=[1,2,3,4,5]
list2=[3,4,5,6,7]

# %%
common = list(set(list1) & set(list2))

# %%
common
# Out:
# [3, 4, 5]

# %%
list_num=[9,8,7,6,5,4,3]

# %%
sort_list=sorted(list_num)

# %%
sort_list
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
set(list1) | set(list2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}
