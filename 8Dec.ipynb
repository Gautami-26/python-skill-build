# %%
# file handling

#read, append, write

# %%
with open("sample.txt","w") as f:
    f.write("Hello good morning ,today gautami is excited for the class")

# %%
with open("sample.txt","r") as f:
    data=f.read()
    print(data)
# Out:
# Hello good morning ,today gautami is excited for the class

# %%
with open("sample.txt","a") as f:
    f.write("\n he has got exams,yet he is happy as always")

# %%
with open("sample.txt","r") as f:
    data=f.read()
    print(data)
# Out:
# Hello good morning ,today gautami is excited for the classhe has got exams,yet he is happy as always
# he has got exams,yet he is happy as always
#  he has got exams,yet he is happy as always

# %%
with open("sample.txt","r") as f:
    for line in f:
        print("*"*25)
        print(line.strip())
        print("*"*25)
# Out:
# *************************
# Hello good morning ,today gautami is excited for the classhe has got exams,yet he is happy as always
# *************************
# *************************
# he has got exams,yet he is happy as always
# *************************
# *************************
# he has got exams,yet he is happy as always
# *************************

# %%
with open("sample.txt",'r') as f:
    char_count=f.read()
    print("Character count:",len(char_count))
# Out:
# Character count: 187

# %%
with open("sample.txt","r") as f:
    lines=f.readlines()
    print("total lines",len(lines))
# Out:
# total lines 3

# %%
with open("sample.txt","a") as f:
    f.write("\n Gautami needs clean text,hence i wrote this line")

# %%
with open("sample.txt","r") as f:
    for line in f:
        print("\n")

# %%
with open("sample.txt",'r') as f:
    with open("copy_of_sample.txt",'w') as copy_cat:
        copy_cat.write(f.read())

# %%
with open("copy_of_sample.txt","r") as f:
    lines=f.readlines()
    print("total lines",len(lines))
# Out:
# total lines 4

# %%
name="Gautami"
with open("sample.txt","r") as f:
    if name in f.read():
        print("Name found")
    else:
        print("Name not found")
# Out:
# Name found

# %%
#assignment
append the name:"rahul"
name="Rahul"
lowerc case:
name found

# %%
with open("sample.txt","a") as f:
    f.write("\n rahul")

name='Rahul'
with open("sample.txt","r") as f:
 

    if name in data:
        print("name found(case sensitive)")    
    else:
        print("Name not found(case )")
# Out:
# Name not found

# %%
with open("sample.txt",'r') as f:
    lines=f.readlines()
    print(lines[-1])
# Out:
#  rahul

# %%
with open("long_doc.txt",'r') as f:
    text=f.read()
    words=text.split()
    print(len(words))
# Out:
# 216

# %%
word="file"
count=0
with open('long_doc.txt','r') as f:
    text=f.read().lower()
    count=text.count(word)
print("freq:",count)
# Out:
# freq: 0

# %%
with open('copy_of_sample.txt','r') as f:
    lines=[line.strip() for line in f]
print(len(lines))
# Out:
# 4
