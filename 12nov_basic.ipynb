# %%
print("hello")

# %%
a=[10,20,30,40]

# %%
b=a

# %%
b

# %%
print ("Day 2")

student_name = "Gautami"
age=21
print(type(student_name))
print(type(age))
# Out:
# Day 2
# <class 'str'>
# <class 'int'>
